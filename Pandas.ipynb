# %% [markdown]
# ## PANDAS

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# ## Create Dataframe

# %%
## using list
df= pd.DataFrame([11,12,13], columns=["col_name"])
print(df)
# Out:
#    col_name
# 0        11
# 1        12
# 2        13

# %%
df1 = pd.DataFrame([True,23,"pandas"],columns=["list"])
print(df)
# Out:
#      list
# 0    True
# 1      23
# 2  pandas

# %%
print(type(df1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
## using dictinary of list
data={
    " name ":["sneha","angel","riya"],
    " age ":[16,17,18],
    "salary":[400040,290600,34829]
}
print(data)
# Out:
# {' name ': ['sneha', 'angel', 'riya'], ' age ': [16, 17, 18], 'salary': [400040, 290600, 34829]}

# %%
df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#    name    age   salary
# 0  sneha     16  400040
# 1  angel     17  290600
# 2   riya     18   34829
# <class 'pandas.core.frame.DataFrame'>

# %%
df.head()
# Out:
#    name    age   salary
# 0  sneha     16  400040
# 1  angel     17  290600
# 2   riya     18   34829

# %%
df.tail(1)
# Out:
#    name    age   salary
# 2   riya     18   34829

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index([' name ', ' age ', 'salary'], dtype='object')

# %%
df.rename(columns={"salary":"Monthly salary"},inplace=True)

# %%
df
print(df)
# Out:
#    name    age   Monthly salary
# 0  sneha     16          400040
# 1  angel     17          290600
# 2   riya     18           34829

# %%
df
# Out:
#    name    age   Monthly salary
# 0  sneha     16          400040
# 1  angel     17          290600
# 2   riya     18           34829

# %%
df.info
# Out:
# <bound method DataFrame.info of    name    age   Monthly salary
# 0  sneha     16          400040
# 1  angel     17          290600
# 2   riya     18           34829>

# %%
df.describe()
# Out:
#         age   Monthly salary
# count    3.0        3.000000
# mean    17.0   241823.000000
# std      1.0   187427.760556
# min     16.0    34829.000000
# 25%     16.5   162714.500000
# 50%     17.0   290600.000000
# 75%     17.5   345320.000000
# max     18.0   400040.000000

# %%
## create , save and load file
df.to_csv("test_data.csv" , index=False)

# %%
load_df=pd.read_csv("test_data.csv")
load_df
pd.read_csv("test_data.csv")
# Out:
#    name    age   Monthly salary
# 0  sneha     16          400040
# 1  angel     17          290600
# 2   riya     18           34829
